# %% [markdown]
# # Exemplos - leitura de imagens com a OpenCV

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print "OpenCV Version : %s " % cv2.__version__
# Out:
# OpenCV Version : 2.4.12

# %% [markdown]
# # Leitura de imagens

# %%
grid = cv2.imread("img9x9.png")

# %%
grid_rgb = cv2.cvtColor(grid, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(grid_rgb,interpolation="none")

# %% [markdown]
# No OpenCV as imagens são numpy

# %%
type(grid_rgb)
# Out:
# numpy.ndarray

# %%
grid_rgb.transpose()
# Out:
# array([[[255, 255,   2],
#         [255,   1, 255],
#         [  1, 255, 255]],
#
#        [[  5, 255, 255],
#         [255, 255, 255],
#         [  1, 255,   1]],
#
#        [[  5, 255, 255],
#         [255,   1,  21],
#         [255, 255, 255]]], dtype=uint8)

# %%
arara = cv2.imread("arara_medium.jpg")

# %%
plt.imshow(arara)

# %%
arara_rgb = cv2.cvtColor(arara, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(arara_rgb)

# %%
arara_rgb.shape
# Out:
# (333L, 500L, 3L)

# %% [markdown]
# # Separando os canais da imagem

# %%
arara_r = arara_rgb[:,:,0]

# %%
plt.imshow(arara_r, cmap='Greys_r')

# %%
arara_g = arara_rgb[:,:,1]

# %%
plt.imshow(arara_g, cmap='Greys_r')

# %%
arara_b = arara_rgb[:,:,2]

# %%
plt.imshow(arara_b, cmap='Greys_r')

# %% [markdown]
# # Input da webcam

# %%
webcam = cv2.VideoCapture(1) # Tente vários IDs para descobrir qual é em sua webcam

# %%
t.sleep(3) # Espera a webcam ficar pronta

# %%
val, image = webcam.read()

# %%
val  # Checa se um frame chegou
# Out:
# True

# %%
webcam.release() # fecha a webcam

# %%
plt.imshow(image)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)
